# %% [markdown]
# <a href="https://colab.research.google.com/github/camilorey/material_clases/blob/main/consultando_datos_abiertos_saber11_20191.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as Pandas

# %% [markdown]
# Vamos a cargar el archivo de las pruebas Saber 11 usando el SODA API.

# %%
#read data from Datos Abiertos
documentAddress = 'https://www.datos.gov.co/resource/tkn6-e4ic.json'
saber11DataFrame = Pandas.read_json(documentAddress)
saber11DataFrame.head()
# Out:
#   estu_tipodocumento  ... estu_generacion_e
# 0                 TI  ...                NO
# 1                 CC  ...                NO
# 2                 TI  ...                NO
# 3                 CC  ...                NO
# 4                 CC  ...                NO
#
# [5 rows x 82 columns]

# %%
#variables en archivo
variablesPersonalesBinarias = ['fami_tieneinternet', 'fami_tieneserviciotv',\
                     'fami_tienecomputador', 'fami_tienehornomicroogas',\
                     'fami_tieneautomovil', 'fami_tieneconsolavideojuegos']

variablesPersonalesOrdinales = ['fami_estratovivienda','fami_educacionpadre', 'fami_educacionmadre','fami_trabajolaborpadre',\
                      'fami_trabajolabormadre','fami_numlibros', \
                      'fami_comecarnepescadohuevo',\
                      'fami_situacioneconomica', 'estu_dedicacionlecturadiaria',\
                      'estu_horassemanatrabaja','estu_nse_individual']

#variables del examen
variablesExamen = ['percentil_lectura_critica', 'desemp_lectura_critica',\
                   'percentil_matematicas', 'desemp_matematicas',\
                   'percentil_c_naturales', 'desemp_c_naturales',\
                   'percentil_sociales_ciudadanas',\
                   'desemp_sociales_ciudadanas',  'percentil_ingles',\
                   'percentil_global']
#variables de puntajes
puntajesExamen = ['punt_matematicas','punt_c_naturales','punt_sociales_ciudadanas','punt_ingles','punt_lectura_critica']

#variables del colegio
variablesColegio = ['cole_naturaleza','cole_bilingue','cole_caracter','cole_genero','cole_calendario','cole_jornada']
#variables objetivo aqui
variableObjetivo = ['desemp_ingles','punt_global']

# %% [markdown]
# analicemos las variables para ver consistencias e inconsistencias

# %%
for varBinaria in variablesPersonalesBinarias:
  resultados = saber11DataFrame[varBinaria].value_counts()
  print(varBinaria)
  print(resultados)
# Out:
# fami_tieneinternet
# Si    770
# No    152
# -      78
# Name: fami_tieneinternet, dtype: int64
# fami_tieneserviciotv
# Si    795
# No    128
# -      77
# Name: fami_tieneserviciotv, dtype: int64
# fami_tienecomputador
# Si    739
# No    209
# -      52
# Name: fami_tienecomputador, dtype: int64
# fami_tienehornomicroogas
# Si    665
# No    280
# -      55
# Name: fami_tienehornomicroogas, dtype: int64
# fami_tieneautomovil
# No    479
# Si    465
# -      56
# Name: fami_tieneautomovil, dtype: int64
# fami_tieneconsolavideojuegos
# No    515
# Si    426
# -      59
# Name: fami_tieneconsolavideojuegos, dtype: int64

# %% [markdown]
# Analicemos las variables ordinales

# %%
for varOrdinal in variablesPersonalesOrdinales:
  values = saber11DataFrame[varOrdinal].value_counts()
  print(varOrdinal)
  print(values)
# Out:
# fami_estratovivienda
# Estrato 3      240
# Estrato 2      209
# Estrato 6      135
# Estrato 4      123
# Estrato 1      100
# Estrato 5       92
# -               81
# Sin Estrato     20
# Name: fami_estratovivienda, dtype: int64
# fami_educacionpadre
# Educación profesional completa          205
# Postgrado                               155
# Secundaria (Bachillerato) completa      152
# Primaria incompleta                      95
# -                                        76
# Técnica o tecnológica completa           66
# Secundaria (Bachillerato) incompleta     62
# No sabe                                  55
# Primaria completa                        52
# Ninguno                                  40
# Educación profesional incompleta         16
# Técnica o tecnológica incompleta         14
# No Aplica                                12
# Name: fami_educacionpadre, dtype: int64
# fami_educacionmadre
# Educación profesional completa          239
# Secundaria (Bachillerato) completa      174
# Postgrado                               133
# Primaria incompleta                      88
# -                                        77
# Secundaria (Bachillerato) incompleta     73
# Técnica o tecnológica completa           72
# Primaria completa                        57
# Educación profesional incompleta         29
# Ninguno                                  22
# Técnica o tecnológica incompleta         21
# No sabe                                  11
# No Aplica                                 4
# Name: fami_educacionmadre, dtype: int64
# fami_trabajolaborpadre
# Trabaja como profesional (por ejemplo médico, abogado, ingeniero)                                       195
# No aplica                                                                                                96
# Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial                             96
# Trabaja por cuenta propia (por ejemplo plomero, electricista)                                            88
# No sabe                                                                                                  72
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc     69
# Es agricultor, pesquero o jornalero                                                                      62
# Es operario de máquinas o conduce vehículos (taxita, chofer)                                             59
# Trabaja en el hogar, no trabaja o estudia                                                                57
# -                                                                                                        54
# Pensionado                                                                                               43
# Trabaja como personal de limpieza, mantenimiento, seguridad o construcción                               42
# Es vendedor o trabaja en atención al público                                                             40
# Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)                   27
# Name: fami_trabajolaborpadre, dtype: int64
# fami_trabajolabormadre
# Trabaja en el hogar, no trabaja o estudia                                                               290
# Trabaja como profesional (por ejemplo médico, abogado, ingeniero)                                       181
# Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)                   81
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc     70
# Es vendedor o trabaja en atención al público                                                             60
# Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial                             60
# Trabaja como personal de limpieza, mantenimiento, seguridad o construcción                               56
# No aplica                                                                                                52
# -                                                                                                        48
# Trabaja por cuenta propia (por ejemplo plomero, electricista)                                            28
# Es agricultor, pesquero o jornalero                                                                      24
# No sabe                                                                                                  20
# Es operario de máquinas o conduce vehículos (taxita, chofer)                                             17
# Pensionado                                                                                               13
# Name: fami_trabajolabormadre, dtype: int64
# fami_numlibros
# 0 A 10 LIBROS        259
# 26 A 100 LIBROS      233
# 11 A 25 LIBROS       213
# MÁS DE 100 LIBROS    205
# -                     90
# Name: fami_numlibros, dtype: int64
# fami_comecarnepescadohuevo
# Todos o casi todos los días     555
# 3 a 5 veces por semana          192
# 1 o 2 veces por semana          140
# -                                79
# Nunca o rara vez comemos eso     34
# Name: fami_comecarnepescadohuevo, dtype: int64
# fami_situacioneconomica
# Igual    581
# Mejor    255
# Peor     110
# -         54
# Name: fami_situacioneconomica, dtype: int64
# estu_dedicacionlecturadiaria
# 30 minutos o menos            333
# Entre 30 y 60 minutos         273
# No leo por entretenimiento    192
# Entre 1 y 2 horas              98
# -                              78
# Más de 2 horas                 26
# Name: estu_dedicacionlecturadiaria, dtype: int64
# estu_horassemanatrabaja
# 0                      567
# Menos de 10 horas      136
# Más de 30 horas        129
# Entre 11 y 20 horas     81
# -                       50
# Entre 21 y 30 horas     37
# Name: estu_horassemanatrabaja, dtype: int64
# estu_nse_individual
# 4.0    350
# 3.0    298
# 2.0    208
# 1.0     86
# Name: estu_nse_individual, dtype: int64

# %% [markdown]
# vamos a retirar de la base de datos todos los -

# %%
variablesALimpiar = variablesPersonalesBinarias + variablesPersonalesOrdinales
registrosConProblemas = []
for indice in range(len(saber11DataFrame)):
  contieneMenos = False
  for var in variablesALimpiar:
    contieneMenos = contieneMenos or saber11DataFrame.iloc[indice][var] == '-'
  if contieneMenos:
    registrosConProblemas.append(indice)
print('Registros con problemas',len(registrosConProblemas))
# Out:
# Registros con problemas 144

# %%
saber11DataFrame = saber11DataFrame.drop(saber11DataFrame.index[registrosConProblemas])

# %%
saber11DataFrame
# Out:
#     estu_tipodocumento  ... estu_generacion_e
# 0                   TI  ...                NO
# 1                   CC  ...                NO
# 2                   TI  ...                NO
# 3                   CC  ...                NO
# 4                   CC  ...                NO
# ..                 ...  ...               ...
# 995                 TI  ...                NO
# 996                 TI  ...                NO
# 997                 TI  ...                NO
# 998                 TI  ...                NO
# 999                 TI  ...                NO
#
# [856 rows x 82 columns]

# %% [markdown]
# sub dividir variables

# %%
caracteristicas = ['fami_tieneinternet','fami_numlibros','estu_nse_individual']
variableObjetivo = 'desemp_ingles'
subDataSaber11 = saber11DataFrame[caracteristicas+[variableObjetivo]]
subDataSaber11
# Out:
#     fami_tieneinternet     fami_numlibros  estu_nse_individual desemp_ingles
# 0                   Si      0 A 10 LIBROS                  3.0            A1
# 1                   Si     11 A 25 LIBROS                  2.0            A-
# 2                   Si      0 A 10 LIBROS                  2.0            A1
# 3                   Si      0 A 10 LIBROS                  3.0            A2
# 4                   Si  MÁS DE 100 LIBROS                  4.0            B1
# ..                 ...                ...                  ...           ...
# 995                 No      0 A 10 LIBROS                  1.0            A1
# 996                 Si      0 A 10 LIBROS                  3.0            A2
# 997                 Si      0 A 10 LIBROS                  4.0            A2
# 998                 Si      0 A 10 LIBROS                  4.0            A-
# 999                 No     11 A 25 LIBROS                  3.0            A1
#
# [856 rows x 4 columns]

# %% [markdown]
# Vamos a reemplazar Si y No por 0 y 1

# %%
#subDataSaber11['fami_tieneinternet'] = subDataSaber11['fami_tieneinternet'].map({'Si':1,'No':0})

# %%
diccionarioNumLibros = {'0 A 10 LIBROS': 1,
                             '11 A 25 LIBROS':2,
                             '26 A 100 LIBROS':3, 
                             'MÁS DE 100 LIBROS':4}
diccionarioNivelesIngles = {'A-':1,'A1':2,'A2':3,'B1':4,'B+':5}
subDataSaber11['desemp_ingles'] = subDataSaber11['desemp_ingles'].map(diccionarioNivelesIngles)
subDataSaber11['fami_numlibros'] = subDataSaber11['fami_numlibros'].map(diccionarioNumLibros)
subDataSaber11.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#    fami_tieneinternet  fami_numlibros  estu_nse_individual  desemp_ingles
# 0                   1               1                  3.0              2
# 1                   1               2                  2.0              1
# 2                   1               1                  2.0              2
# 3                   1               1                  3.0              3
# 4                   1               4                  4.0              4
